# %% [markdown]
# <a href="https://colab.research.google.com/github/25gs10526-cpu/2026ai/blob/main/%ED%97%88%EC%B0%AC%EA%B2%BD_%EC%9D%B8%EA%B8%B0%EC%B4%88(%EA%B9%83%ED%97%99).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Hello World')
# Out:
# Hello World

# %%
print('hello world')
# Out:
# hello world
